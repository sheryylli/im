# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# multivariate: Age, Gender, Tobacco, Acute renal failure (ARF), Glasgow coma scale (GCS), Level of consciousness (AVPU),
# Pao2, Hco3, Sodium, Creatinine, Potassium, Hematocrit, Arterial ph, Hemoglobin, Blood lactate, Platelet
# count, Blood urea nitrogen (BUN), White blood cell count (WBC)
# get Cardiac arrest patients

# %%
admissions = pd.read_csv("admissions.csv")

# %%
admissions.head()
# Out:
#    hadm_id  subject_id            admit_dt            disch_dt
# 0        2       24807   8/7/3033 00:00:00  17/7/3033 00:00:00
# 1        3        7675  16/5/3388 00:00:00  21/5/3388 00:00:00
# 2        6       23547   3/4/3381 00:00:00  22/4/3381 00:00:00
# 3       10       14884  28/8/3015 00:00:00   5/9/3015 00:00:00
# 4       12        8652  11/9/3125 00:00:00  22/9/3125 00:00:00

# %%
chartdurations = pd.read_csv("a_chartdurations.csv")

# %%
mimic2 = pd.merge(admissions, chartdurations)
mimic2.head()
# Out:
#    hadm_id  subject_id           admit_dt            disch_dt  icustay_id  \
# 0        2       24807  8/7/3033 00:00:00  17/7/3033 00:00:00     30797.0
# 1        2       24807  8/7/3033 00:00:00  17/7/3033 00:00:00     30797.0
# 2        2       24807  8/7/3033 00:00:00  17/7/3033 00:00:00     30797.0
# 3        2       24807  8/7/3033 00:00:00  17/7/3033 00:00:00     30797.0
# 4        2       24807  8/7/3033 00:00:00  17/7/3033 00:00:00     30797.0
#
#    itemid  elemid           starttime       startrealtime             endtime  \
# 0     432       0  17/4/3033 01:00:00  17/4/3033 01:59:00  19/4/3033 20:10:00
# 1     428       0  17/4/3033 01:00:00  17/4/3033 01:59:00  19/4/3033 20:10:00
# 2     425       0  17/4/3033 01:00:00  17/4/3033 01:59:00  19/4/3033 20:10:00
# 3     418       0  17/4/3033 01:00:00  17/4/3033 01:26:00  19/4/3033 20:10:00
# 4     417       0  17/4/3033 01:00:00  17/4/3033 01:26:00  19/4/3033 20:10:00
#
#    cuid  duration
# 0    69    4030.0
# 1    69    4030.0
# 2    69    4030.0
# 3    69    4030.0
# 4    69    4030.0

# %%
labevents = pd.read_csv("labevents.csv")
labevents.head()
# Out:
#    subject_id  hadm_id  icustay_id  itemid           charttime value  \
# 0          56  28766.0         NaN   50124  17/1/2644 00:30:00  HOLD
# 1          56  28766.0         NaN   50112  17/1/2644 00:30:00   155
# 2          56  28766.0         NaN   50177  17/1/2644 00:30:00    21
# 3          56  28766.0         NaN   50090  17/1/2644 00:30:00   0.7
# 4          56  28766.0         NaN   50159  17/1/2644 00:30:00   128
#
#    valuenum      flag valueuom
# 0       NaN       NaN      NaN
# 1     155.0  abnormal    mg/dL
# 2      21.0  abnormal    mg/dL
# 3       0.7       NaN    mg/dL
# 4     128.0  abnormal    mEq/L

# %%
d_codeditems = pd.read_csv("d_codeditems.csv")
microbio = pd.read_csv("microbiologyevents.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d_codeditems.columns = ['spec_itemid', 'code', 'type', 'category', 'label', 'description']

# %%
d_codeditems.head()
# Out:
#    spec_itemid  code      type category label  \
# 0        60001  001   HFCA_DRG      NaN   NaN
# 1        60002  001   HFCA_DRG      NaN   NaN
# 2        60003  001   HFCA_DRG      NaN   NaN
# 3        60004  002   HFCA_DRG      NaN   NaN
# 4        60005  002   HFCA_DRG      NaN   NaN
#
#                                 description
# 0  CRANIOTOMY AGE >17 EXCEPT FOR TRAUMA
# 1  CRANIOTOMY AGE >17 W CC
# 2  HEART TRANSPLANT OR IMPLANT OF HEART ASS
# 3  CRANIOTOMY AGE >17 W/O CC
# 4  CRANIOTOMY FOR TRAUMA AGE >17

# %%
lab = pd.merge(d_codeditems, microbio)

# %%
lab
# Out:
#        spec_itemid   code          type  category             label  \
# 0            70002     TS  MICROBIOLOGY  SPECIMEN  THROAT FOR STREP
# 1            70002     TS  MICROBIOLOGY  SPECIMEN  THROAT FOR STREP
# 2            70002     TS  MICROBIOLOGY  SPECIMEN  THROAT FOR STREP
# 3            70002     TS  MICROBIOLOGY  SPECIMEN  THROAT FOR STREP
# 4            70002     TS  MICROBIOLOGY  SPECIMEN  THROAT FOR STREP
# ...            ...    ...           ...       ...               ...
# 89995        70093  TOXOP  MICROBIOLOGY  SPECIMEN      Blood (Toxo)
# 89996        70093  TOXOP  MICROBIOLOGY  SPECIMEN      Blood (Toxo)
# 89997        70093  TOXOP  MICROBIOLOGY  SPECIMEN      Blood (Toxo)
# 89998        70093  TOXOP  MICROBIOLOGY  SPECIMEN      Blood (Toxo)
# 89999        70093  TOXOP  MICROBIOLOGY  SPECIMEN      Blood (Toxo)
#
#       description  subject_id  hadm_id            charttime  org_itemid  \
# 0             NaN         618    13394    2/4/3063 18:29:00       80001
# 1             NaN        3677    12284  18/12/3266 22:11:00       80001
# 2             NaN        7476     2606   28/6/3088 20:02:00       80001
# 3             NaN        7726      312   13/4/3137 15:10:00       80001
# 4             NaN        8231     7668   12/1/3207 07:57:00       80001
# ...           ...         ...      ...                  ...         ...
# 89995         NaN       28655    31911  14/11/3141 10:45:00       80001
# 89996         NaN       30845    32092   21/9/3257 03:28:00       80001
# 89997         NaN       31241    32339   23/7/2966 04:16:00       80001
# 89998         NaN       32285    34875   18/2/2826 17:43:00       80001
# 89999         NaN       32624    31775   15/6/3219 15:05:00       80001
#
#        isolate_num  ab_itemid dilution_amount dilution_comparison  \
# 0              NaN      90001             NaN                 NaN
# 1              NaN      90001             NaN                 NaN
# 2              NaN      90001             NaN                 NaN
# 3              NaN      90001             NaN                 NaN
# 4              NaN      90001             NaN                 NaN
# ...            ...        ...             ...                 ...
# 89995          NaN      90001             NaN                 NaN
# 89996          NaN      90001             NaN                 NaN
# 89997          NaN      90001             NaN                 NaN
# 89998          NaN      90001             NaN                 NaN
# 89999          NaN      90001             NaN                 NaN
#
#       interpretation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 89995            NaN
# 89996            NaN
# 89997            NaN
# 89998            NaN
# 89999            NaN
#
# [90000 rows x 15 columns]

# %%
for (columnName, columnData) in microbio.iteritems():
    print('Column Name : ', columnName)
    print('Column Contents : ', columnData.values)
# Out:
# Column Name :  subject_id
# Column Contents :  [   37    37    37 ... 32763 32763 32763]
# Column Name :  hadm_id
# Column Contents :  [18052 18052 18052 ... 33007 33007 33007]
# Column Name :  charttime
# Column Contents :  ['14/8/3264 23:00:00' '15/8/3264 06:30:00' '15/8/3264 21:55:00' ...
#  '6/7/2724 08:48:00' '6/7/2724 10:01:00' '6/7/2724 10:01:00']
# Column Name :  spec_itemid
# Column Contents :  [70012 70012 70079 ... 70079 70062 70062]
# Column Name :  org_itemid
# Column Contents :  [80001 80001 80001 ... 80001 80026 80075]
# Column Name :  isolate_num
# Column Contents :  [nan nan nan ... nan  1.  1.]
# Column Name :  ab_itemid
# Column Contents :  [90001 90001 90001 ... 90001 90001 90001]
# Column Name :  dilution_amount
# Column Contents :  [nan nan nan ... nan nan nan]
# Column Name :  dilution_comparison
# Column Contents :  [nan nan nan ... nan nan nan]
# Column Name :  interpretation
# Column Contents :  [nan nan nan ... nan nan nan]

# %%
additives = pd.read_csv("additives.csv")
d_ioi = pd.read_csv("d_ioitems.csv")

# %%
additives.head()
# Out:
#    subject_id  icustay_id  itemid  ioitemid           charttime  elemid  cgid  \
# 0          56         NaN      26       134  17/1/2644 02:00:00     100  1084
# 1          56        62.0      50       178  17/1/2644 03:00:00     100  5692
# 2          56        62.0      26       134  18/1/2644 03:00:00     300   940
# 3           3         4.0      43       140   7/9/2682 22:00:00     100    -1
# 4           3         4.0     128       218   7/9/2682 22:00:00     100    -1
#
#    cuid  amount doseunits             route
# 0     1    20.0       mEq  Intravenous Push
# 1     1    50.0  mcgkgmin           IV Drip
# 2     1    20.0       mEq  Intravenous Push
# 3    69   400.0  mcgkgmin           IV Drip
# 4    69    60.0  mcgkgmin           IV Drip

# %%
d_ioi.head()
# Out:
#    itemid                 label category
# 0      -1                   NaN      NaN
# 1       1          24h Total In      NaN
# 2       2         24h Total Out      NaN
# 3       3  Blood Products Total      NaN
# 4       4  Cerebral Drain Total      NaN

# %%
additives_io = pd.merge(additives, d_ioi)

# %%
additives_io.tail()
# Out:
#        subject_id  icustay_id  itemid  ioitemid           charttime  elemid  \
# 27078       26125     40715.0     151      6210  13/9/3360 13:00:00     100
# 27079       18093     22535.0     312      3201  11/3/3406 21:00:00     100
# 27080       18384     22890.0     147      1658   7/8/3149 15:00:00     100
# 27081       20367     25372.0     166       257  17/3/3204 23:00:00     303
# 27082       20367     25372.0     166       672  18/3/3204 09:00:00     204
#
#        cgid  cuid  amount doseunits                 route  \
# 27078  8889    53    12.0  mcgkgmin               IV Drip
# 27079  4623    75   500.0  mcgkgmin                  Drip
# 27080  2380    69    50.0        mg               IV Drip
# 27081  3246    54   800.0       str  Gastric/Feeding Tube
# 27082  7882    54   800.0       str  Gastric/Feeding Tube
#
#                                         label      category
# 27078             .45% Normal Saline 1000.0ml  IV Infusions
# 27079  D5W 250.0ml + 500mghr Morphine Sulfate  IV Infusions
# 27080  D5W 250.0ml + 100mcgmin Nitroglycerine  IV Infusions
# 27081              D5W 60.0ml + 60mghr Ativan  IV Infusions
# 27082              D5W 60.0ml + 60mghr Ativan  IV Infusions

# %% [markdown]
# bookmark

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#import csv
#rm_quote = lambda x: x.replace('"', '')
#df = pd.read_csv('/content/drive/MyDrive/mimic/chartevents.csv', header = None, sep=',',quoting=csv.QUOTE_NONE, encoding='utf-8', names=["subject_id","icustay_id","itemid","charttime","elemid","realtime","cgid","cuid","value1","value1num","value1uom","value2","value2num","value2uom","resultstatus","stopped"])
df = pd.read_csv('/content/drive/MyDrive/mimic/chartevents.csv', header = None, sep=',', encoding='utf-8', 
                 names=["subject_id","icustay_id","itemid","charttime","elemid","realtime","cgid","cuid","value1","value1num","value1uom","value2","value2num","value2uom","resultstatus","stopped"],                 
                 keep_default_na=False, nrows=50000)


print(df)
#df = df.rename(columns=rm_quote)
# Out:
#        subject_id  icustay_id  itemid           charttime  elemid  \
# 0      subject_id  icustay_id  itemid           charttime  elemid
# 1              56          62     926  17/1/2644 02:02:00    1000
# 2              56          62     920  17/1/2644 02:02:00    1034
# 3              56          62      69  17/1/2644 02:02:00    1033
# 4              56          62     762  17/1/2644 02:02:00    1032
# ...           ...         ...     ...                 ...     ...
# 49995         106         123     325  26/7/2993 03:00:00       0
# 49996         106         123     137  26/7/2993 03:00:00       0
# 49997         106         123     674  26/7/2993 03:00:00       0
# 49998         106         123    5817  26/7/2993 03:00:00       0
# 49999         106         123      54  26/7/2993 03:00:00       0
#
#                  realtime  cgid  cuid           value1  value1num  value1uom  \
# 0                realtime  cgid  cuid           value1  value1num  value1uom
# 1      17/1/2644 02:02:00     8     1              NSP
# 2      17/1/2644 02:02:00     8     1
# 3      17/1/2644 02:02:00     8     1
# 4      17/1/2644 02:02:00     8     1
# ...                   ...   ...   ...              ...        ...        ...
# 49995  26/7/2993 03:00:00  7594     1              WNL
# 49996  26/7/2993 03:00:00  7594     1         Impaired
# 49997  26/7/2993 03:00:00  7594     1           Rectal
# 49998  26/7/2993 03:00:00  7594     1               90         90       mmHg
# 49999  26/7/2993 03:00:00  7594     1  2 Person Assist
#
#        value2  value2num  value2uom  resultstatus   stopped
# 0      value2  value2num  value2uom  resultstatus   stopped
# 1
# 2
# 3
# 4
# ...       ...        ...        ...           ...       ...
# 49995                                              NotStopd
# 49996                                              NotStopd
# 49997                                              NotStopd
# 49998     160        160       mmHg                NotStopd
# 49999                                              NotStopd
#
# [50000 rows x 16 columns]
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,2,4,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    subject_id  icustay_id  itemid           charttime  elemid  \
# 0  subject_id  icustay_id  itemid           charttime  elemid
# 1          56          62     926  17/1/2644 02:02:00    1000
# 2          56          62     920  17/1/2644 02:02:00    1034
# 3          56          62      69  17/1/2644 02:02:00    1033
# 4          56          62     762  17/1/2644 02:02:00    1032
#
#              realtime  cgid  cuid  value1  value1num  value1uom  value2  \
# 0            realtime  cgid  cuid  value1  value1num  value1uom  value2
# 1  17/1/2644 02:02:00     8     1     NSP
# 2  17/1/2644 02:02:00     8     1
# 3  17/1/2644 02:02:00     8     1
# 4  17/1/2644 02:02:00     8     1
#
#    value2num  value2uom  resultstatus  stopped
# 0  value2num  value2uom  resultstatus  stopped
# 1
# 2
# 3
# 4

# %%
df1 = df.drop([0], axis=0, inplace=False)

# %%
df1.head()
# Out:
#   subject_id icustay_id itemid           charttime elemid            realtime  \
# 1         56         62    926  17/1/2644 02:02:00   1000  17/1/2644 02:02:00
# 2         56         62    920  17/1/2644 02:02:00   1034  17/1/2644 02:02:00
# 3         56         62     69  17/1/2644 02:02:00   1033  17/1/2644 02:02:00
# 4         56         62    762  17/1/2644 02:02:00   1032  17/1/2644 02:02:00
# 5         56         62    919  17/1/2644 02:02:00   1026  17/1/2644 02:02:00
#
#   cgid cuid value1 value1num value1uom value2 value2num value2uom  \
# 1    8    1    NSP
# 2    8    1
# 3    8    1
# 4    8    1
# 5    8    1    NSU
#
#   resultstatus stopped
# 1
# 2
# 3
# 4
# 5

# %%
df.head()
# Out:
#    subject_id  icustay_id  itemid           charttime  elemid  \
# 0  subject_id  icustay_id  itemid           charttime  elemid
# 1          56          62     926  17/1/2644 02:02:00    1000
# 2          56          62     920  17/1/2644 02:02:00    1034
# 3          56          62      69  17/1/2644 02:02:00    1033
# 4          56          62     762  17/1/2644 02:02:00    1032
#
#              realtime  cgid  cuid  value1  value1num  value1uom  value2  \
# 0            realtime  cgid  cuid  value1  value1num  value1uom  value2
# 1  17/1/2644 02:02:00     8     1     NSP
# 2  17/1/2644 02:02:00     8     1
# 3  17/1/2644 02:02:00     8     1
# 4  17/1/2644 02:02:00     8     1
#
#    value2num  value2uom  resultstatus  stopped
# 0  value2num  value2uom  resultstatus  stopped
# 1
# 2
# 3
# 4

# %%
chart_d = pd.read_csv('d_chartitems.csv', skipinitialspace=True, dtype = {'label' : str })

# %%
chart_d.head()
# Out:
#    itemid                label category description
# 0       1       % Inspir. Time      NaN         NaN
# 1       2              ABI (L)      NaN         NaN
# 2       3              ABI (R)      NaN         NaN
# 3       4     ABI Ankle BP R/L      NaN         NaN
# 4       5  ABI Brachial BP R/L      NaN         NaN

# %%
chart_d = chart_d.drop('category', axis=1)
chart_d = chart_d.drop('description', axis=1)

# %%
chart_d.columns
# Out:
# Index(['itemid', 'label'], dtype='object')

# %%
df.columns
# Out:
# Index(['subject_id', 'icustay_id', 'itemid', 'charttime', 'elemid', 'realtime',
#        'cgid', 'cuid', 'value1', 'value1num', 'value1uom', 'value2',
#        'value2num', 'value2uom', 'resultstatus', 'stopped'],
#       dtype='object')

# %%
df.head()
# Out:
#    subject_id  icustay_id  itemid           charttime  elemid  \
# 0  subject_id  icustay_id  itemid           charttime  elemid
# 1          56          62     926  17/1/2644 02:02:00    1000
# 2          56          62     920  17/1/2644 02:02:00    1034
# 3          56          62      69  17/1/2644 02:02:00    1033
# 4          56          62     762  17/1/2644 02:02:00    1032
#
#              realtime  cgid  cuid  value1  value1num  value1uom  value2  \
# 0            realtime  cgid  cuid  value1  value1num  value1uom  value2
# 1  17/1/2644 02:02:00     8     1     NSP
# 2  17/1/2644 02:02:00     8     1
# 3  17/1/2644 02:02:00     8     1
# 4  17/1/2644 02:02:00     8     1
#
#    value2num  value2uom  resultstatus  stopped
# 0  value2num  value2uom  resultstatus  stopped
# 1
# 2
# 3
# 4

# %%
df1["itemid"] = df1["itemid"].astype(str)
#df1["itemid"] = [x.replace('"',' ') for x in df1["itemid"]]

# %%
df1.head()
# Out:
#   subject_id icustay_id itemid           charttime elemid            realtime  \
# 1         56         62    926  17/1/2644 02:02:00   1000  17/1/2644 02:02:00
# 2         56         62    920  17/1/2644 02:02:00   1034  17/1/2644 02:02:00
# 3         56         62     69  17/1/2644 02:02:00   1033  17/1/2644 02:02:00
# 4         56         62    762  17/1/2644 02:02:00   1032  17/1/2644 02:02:00
# 5         56         62    919  17/1/2644 02:02:00   1026  17/1/2644 02:02:00
#
#   cgid cuid value1 value1num value1uom value2 value2num value2uom  \
# 1    8    1    NSP
# 2    8    1
# 3    8    1
# 4    8    1
# 5    8    1    NSU
#
#   resultstatus stopped
# 1
# 2
# 3
# 4
# 5

# %%
df1.dtypes
# Out:
# subject_id      object
# icustay_id      object
# itemid          object
# charttime       object
# elemid          object
# realtime        object
# cgid            object
# cuid            object
# value1          object
# value1num       object
# value1uom       object
# value2          object
# value2num       object
# value2uom       object
# resultstatus    object
# stopped         object
# dtype: object

# %%
df1 = df1.drop(df1.columns[[3, 5, 3,6,7,11,12,13,14]], axis=1)  # df.columns is zero-based pd.Index

# %%
df1.head()
df1['subject_id'] = df1['subject_id'].astype('int')
#df1['icustay_id'] = df1['icustay_id'].astype('int')
df1['itemid'] = df1['itemid'].astype('int')
df1['elemid'] = df1['elemid'].astype('int')
#df1['value1num'] = df1['value1num'].astype('int')
df1['value1uom'] = df1['value1uom'].astype('string')
df1['stopped'] = df1['stopped'].astype('string')

# %%
chart_d['itemid'] = chart_d['itemid'].astype(int)

# %%
chart_d.head()
# Out:
#    itemid                label
# 0       1       % Inspir. Time
# 1       2              ABI (L)
# 2       3              ABI (R)
# 3       4     ABI Ankle BP R/L
# 4       5  ABI Brachial BP R/L

# %%
#chart_d['label'] = chart_d['label'].astype('str')
#chart_d['label'].astype('string')
#label_2 = chart_d.astype({'label':'string'})
#chart_d = pd.merge(chart_d, label_2)

# %%
print(chart_d)
# Out:
#       itemid                              label
# 0          1                     % Inspir. Time
# 1          2                            ABI (L)
# 2          3                            ABI (R)
# 3          4                   ABI Ankle BP R/L
# 4          5                ABI Brachial BP R/L
# ...      ...                                ...
# 4827   20005  Pressor Cardiovascular SOFA Score
# 4828   20006      MAP Cardiovascular SOFA Score
# 4829   20007              Neurologic SOFA Score
# 4830   20008                   Renal SOFA Score
# 4831   20009                 Overall SOFA Score
#
# [4832 rows x 2 columns]

# %%
chart_d.head()
# Out:
#    itemid                label
# 0       1       % Inspir. Time
# 1       2              ABI (L)
# 2       3              ABI (R)
# 3       4     ABI Ankle BP R/L
# 4       5  ABI Brachial BP R/L

# %%
#chart_d.update('"' + chart_d[['label']].astype(str) + '"')
chart_d['label'] = chart_d['label'].astype('string')
#chart_d['label'] = chart_d['label'].str.split(',') 
print(chart_d)
# Out:
#       itemid                              label
# 0          1                     % Inspir. Time
# 1          2                            ABI (L)
# 2          3                            ABI (R)
# 3          4                   ABI Ankle BP R/L
# 4          5                ABI Brachial BP R/L
# ...      ...                                ...
# 4827   20005  Pressor Cardiovascular SOFA Score
# 4828   20006      MAP Cardiovascular SOFA Score
# 4829   20007              Neurologic SOFA Score
# 4830   20008                   Renal SOFA Score
# 4831   20009                 Overall SOFA Score
#
# [4832 rows x 2 columns]

# %%
chart_d.dtypes
# Out:
# itemid     int64
# label     string
# dtype: object

# %%
chart = pd.merge(chart_d, df1)

# %%
chart.columns
# Out:
# Index(['itemid', 'label', 'subject_id', 'icustay_id', 'elemid', 'value1',
#        'value1num', 'value1uom', 'stopped'],
#       dtype='object')

# %% [markdown]
# Chart items
# - GCS-198
# - Pao2-490
# - Hco3-812
# - Sodium-837
# - Creatinine- 1525
# - Potassium-1535
# - Hematocrit- 3761
# - Arterial ph- 780
# - Hemoglobin-814
# - Blood lactate- ??
# - Platelet count- 6256
# - BUN-781, 1162?
# - WBC-1542

# %%
numbers = [198, 490, 812, 837, 1525, 1535, 3761, 780,814,6256,1162,1542]
chart = chart.loc[chart['itemid'].isin([198, 490, 812, 837, 1525, 1535, 3761, 780,814,6256,1162,1542])]

# %%
chart.head()
# Out:
#        itemid      label  subject_id icustay_id value1 value1num value1uom  \
# 11887     198  GCS Total          56         62      5         5    points
# 11888     198  GCS Total          56         62     10        10    points
# 11889     198  GCS Total          56         62     10        10    points
# 11890     198  GCS Total          56         62     10        10    points
# 11891     198  GCS Total          56         62     10        10    points
#
#         stopped
# 11887  NotStopd
# 11888  NotStopd
# 11889  NotStopd
# 11890  NotStopd
# 11891  NotStopd

# %%
chart = chart.drop('elemid', axis=1)
#chart = chart.drop('value2', axis=1)
chart = chart.drop('value2uom', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-81074ac1a775> in <module>
# ----> 1 chart = chart.drop('elemid', axis=1)
#       2 #chart = chart.drop('value2', axis=1)
#       3 chart = chart.drop('value2uom', axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['elemid'] not found in axis"

# %%
chart.tail()
# Out:
#        itemid label  subject_id icustay_id value1           value1num  \
# 46119    1542   WBC          21         24   19.4  19.399999999999995
# 46120    1542   WBC          21         24   15.9                15.9
# 46121    1542   WBC         105        121    7.8                 7.8
# 46122    1542   WBC         105        121    4.6                 4.6
# 46123    1542   WBC         117              11.1                11.1
#
#       value1uom   stopped
# 46119            NotStopd
# 46120            NotStopd
# 46121            NotStopd
# 46122            NotStopd
# 46123            NotStopd

# %%
chart = chart.drop('value2num', axis=1)
chart = chart.drop('value1num', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-c2ebd66046c6> in <module>
# ----> 1 chart = chart.drop('value2num', axis=1)
#       2 chart = chart.drop('value1num', axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['value2num'] not found in axis"

# %%
chart = pd.merge(admissions, chart)

# %%
chart.head()
# Out:
#    hadm_id  subject_id            admit_dt            disch_dt  itemid  \
# 0     1459          83  21/3/3424 00:00:00  28/3/3424 00:00:00     198
# 1     1459          83  21/3/3424 00:00:00  28/3/3424 00:00:00     198
# 2     1459          83  21/3/3424 00:00:00  28/3/3424 00:00:00     198
# 3     1459          83  21/3/3424 00:00:00  28/3/3424 00:00:00     198
# 4     1459          83  21/3/3424 00:00:00  28/3/3424 00:00:00     198
#
#        label icustay_id value1 value1num value1uom   stopped
# 0  GCS Total         94     15        15    points  NotStopd
# 1  GCS Total         94     15        15    points  NotStopd
# 2  GCS Total         94     15        15    points  NotStopd
# 3  GCS Total         94     15        15    points  NotStopd
# 4  GCS Total         94     15        15    points  NotStopd

# %%
chart = chart.drop('admit_dt', axis=1)

# %%
chart = chart.drop('disch_dt', axis=1)
chart = chart.drop('charttime', axis=1)
chart = chart.drop('realtime', axis=1)
chart = chart.drop('resultstatus', axis=1)
chart = chart.drop('stopped', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-44098d7166d7> in <module>
#       1 chart = chart.drop('disch_dt', axis=1)
# ----> 2 chart = chart.drop('charttime', axis=1)
#       3 chart = chart.drop('realtime', axis=1)
#       4 chart = chart.drop('resultstatus', axis=1)
#       5 chart = chart.drop('stopped', axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['charttime'] not found in axis"

# %%
chart['subject_id'] = chart['subject_id'].astype("string")
#chart['cgid'] = chart['cgid'].astype("string")
#chart['cuid'] = chart['cuid'].astype("string")
chart['value1'] = chart['value1'].astype("string")
chart['value1uom'] = chart['value1uom'].astype("string")
#chart['category'] = chart['category'].astype("string")
#chart['description'] = chart['description'].astype("string")
chart = chart.drop('stopped', axis=1)

# %%
chart.head()
# Out:
#    hadm_id subject_id  itemid      label icustay_id value1 value1num value1uom
# 0     1459         83     198  GCS Total         94     15        15    points
# 1     1459         83     198  GCS Total         94     15        15    points
# 2     1459         83     198  GCS Total         94     15        15    points
# 3     1459         83     198  GCS Total         94     15        15    points
# 4     1459         83     198  GCS Total         94     15        15    points

# %%
chart = chart.drop('value1num', axis=1)

# %%
#chart['icustay_id'] = chart['icustay_id'].astype("float")
#chart['icustay_id'] = chart['icustay_id'].astype(float)
chart.replace([np.inf, -np.inf], np.nan, inplace=True)
chart.dropna(inplace=True)
chart = chart[chart['subject_id'].notna()]
chart['subject_id'] = chart['icustay_id'].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-596d799bb6b9> in <module>
#       4 chart.dropna(inplace=True)
#       5 chart = chart[chart['subject_id'].notna()]
# ----> 6 chart['subject_id'] = chart['icustay_id'].astype("int")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
chart.dtypes
# Out:
# hadm_id        int64
# subject_id    string
# itemid         int64
# label         string
# icustay_id    object
# value1        string
# value1num     object
# value1uom     string
# dtype: object

# %%
chart.head()
# Out:
#    hadm_id subject_id  itemid      label icustay_id value1 value1uom
# 0     1459         83     198  GCS Total         94     15    points
# 1     1459         83     198  GCS Total         94     15    points
# 2     1459         83     198  GCS Total         94     15    points
# 3     1459         83     198  GCS Total         94     15    points
# 4     1459         83     198  GCS Total         94     15    points

# %% [markdown]
# save this new chart

# %%
chart.to_csv('newchart.csv',sep='\t')

# %% [markdown]
# for zip

# %%
chart.to_csv('newchart.csv.gz', compression='gzip')

# %% [markdown]
# need: age, gender, tobacco, ICU unit, ARF, history, GCS, AVPU

# %%
icu = pd.read_csv('icustay_detail.csv')
icu.head()
# Out:
#    icustay_id  subject_id gender                 dob                  dod  \
# 0          62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 1          41          37      M  11/9/3195 00:00:00  31/12/3265 00:00:00
# 2          89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3          76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4           4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
#
#   expire_flg  subject_icustay_total_num  subject_icustay_seq  hadm_id  \
# 0          Y                          1                    1  28766.0
# 1          Y                          1                    1  18052.0
# 2          Y                          1                    1  15161.0
# 3          Y                          1                    1      NaN
# 4          Y                          1                    1   2075.0
#
#    hospital_total_num  ...  weight_first weight_min weight_max sapsi_first  \
# 0                   1  ...          49.2       49.2       49.2        17.0
# 1                   1  ...           NaN        NaN        NaN        11.0
# 2                   1  ...          72.4       72.4       72.4        14.0
# 3                   0  ...          65.0       64.3       65.0         NaN
# 4                   1  ...          96.8       96.8      108.0        28.0
#
#   sapsi_min  sapsi_max sofa_first  sofa_min  sofa_max matched_waveforms_num
# 0      15.0       17.0        5.0       4.0       5.0                   NaN
# 1      11.0       11.0        2.0       0.0       2.0                   NaN
# 2      11.0       14.0        4.0       3.0       4.0                   NaN
# 3       NaN        NaN        5.0       5.0       5.0                   NaN
# 4       7.0       28.0       14.0       1.0      14.0                   NaN
#
# [5 rows x 42 columns]

# %%
icu = icu.drop('expire_flg', axis=1)
icu = icu.drop('subject_icustay_total_num', axis=1)
icu = icu.drop('sapsi_first', axis=1)
icu = icu.drop('sapsi_min', axis=1)
icu = icu.drop('sofa_first', axis=1)
icu = icu.drop('sofa_min', axis=1)
#icu = icu.drop('sapsi_min', axis=1)
#icu = icu.drop('sofa_max', axis=1)
#icu = icu.drop('matched_waveforms_num', axis=1)

# %%
icu.head()
# Out:
#    icustay_id  subject_id gender                 dob                  dod  \
# 0          62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 1          41          37      M  11/9/3195 00:00:00  31/12/3265 00:00:00
# 2          89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3          76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4           4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
#
#    subject_icustay_seq  hadm_id  hospital_total_num  hospital_seq  \
# 0                    1  28766.0                   1           1.0
# 1                    1  18052.0                   1           1.0
# 2                    1  15161.0                   1           1.0
# 3                    1      NaN                   0           NaN
# 4                    1   2075.0                   1           1.0
#
#   hospital_first_flg  ... icustay_last_careunit icustay_first_service  \
# 0                  Y  ...                   CCU                  SICU
# 1                  Y  ...                  MICU                  MICU
# 2                  Y  ...                  MICU                  MICU
# 3                  N  ...                  FICU                  FICU
# 4                  Y  ...                  MICU                  MICU
#
#   icustay_last_service  height weight_first  weight_min  weight_max sapsi_max  \
# 0                 SICU     NaN         49.2        49.2        49.2      17.0
# 1                 MICU     NaN          NaN         NaN         NaN      11.0
# 2                 MICU     NaN         72.4        72.4        72.4      14.0
# 3                 FICU  165.10         65.0        64.3        65.0       NaN
# 4                 MICU  179.07         96.8        96.8       108.0      28.0
#
#   sofa_max matched_waveforms_num
# 0      5.0                   NaN
# 1      2.0                   NaN
# 2      4.0                   NaN
# 3      5.0                   NaN
# 4     14.0                   NaN
#
# [5 rows x 36 columns]

# %%
icu.columns
# Out:
# Index(['icustay_id', 'subject_id', 'gender', 'dob', 'dod',
#        'subject_icustay_seq', 'hadm_id', 'hospital_total_num', 'hospital_seq',
#        'hospital_first_flg', 'hospital_last_flg', 'hospital_admit_dt',
#        'hospital_disch_dt', 'hospital_los', 'hospital_expire_flg',
#        'icustay_total_num', 'icustay_seq', 'icustay_first_flg',
#        'icustay_last_flg', 'icustay_intime', 'icustay_outtime',
#        'icustay_admit_age', 'icustay_age_group', 'icustay_los',
#        'icustay_expire_flg', 'icustay_first_careunit', 'icustay_last_careunit',
#        'icustay_first_service', 'icustay_last_service', 'height',
#        'weight_first', 'weight_min', 'weight_max', 'sapsi_max', 'sofa_max',
#        'matched_waveforms_num'],
#       dtype='object')

# %%
icu = icu.drop(['subject_icustay_seq', 'hospital_total_num', 'hospital_seq','hospital_first_flg', 'hospital_last_flg','hospital_los', 'hospital_expire_flg','icustay_seq', 'icustay_first_flg', 'icustay_last_flg', 'icustay_intime', 'icustay_outtime','icustay_age_group', 'icustay_los'],
  axis=1)
icu.dropna(subset=['weight_first'])
# Out:
#       icustay_id  subject_id gender                 dob                  dod  \
# 0             62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 2             89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3             76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4              4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
# 6             13          12      M  14/5/2803 00:00:00   9/10/2875 00:00:00
# ...          ...         ...    ...                 ...                  ...
# 5839       47373       32667      M  19/1/2778 00:00:00   27/2/2866 00:00:00
# 5840       47381       32675      M   7/7/2758 00:00:00   29/4/2816 00:00:00
# 5841       47325       32627      M   4/8/2699 00:00:00  14/11/2788 00:00:00
# 5842       47394       32686      M  6/12/2543 00:00:00   27/6/2612 00:00:00
# 5843       47473       32763      M  10/4/2645 00:00:00    9/7/2724 00:00:00
#
#       hadm_id   hospital_admit_dt    hospital_disch_dt  icustay_total_num  \
# 0     28766.0  17/1/2644 00:00:00   23/1/2644 00:00:00                  1
# 2     15161.0  24/3/2778 00:00:00   27/3/2778 00:00:00                  1
# 3         NaN                 NaN                  NaN                  1
# 4      2075.0   7/9/2682 00:00:00   18/9/2682 00:00:00                  1
# 6     12532.0  26/9/2875 00:00:00   9/10/2875 00:00:00                  1
# ...       ...                 ...                  ...                ...
# 5839  36071.0  18/2/2866 00:00:00   27/2/2866 00:00:00                  1
# 5840  35514.0  19/4/2816 00:00:00   29/4/2816 00:00:00                  1
# 5841  33957.0  2/11/2788 00:00:00  14/11/2788 00:00:00                  1
# 5842  30102.0  27/5/2612 00:00:00   27/6/2612 00:00:00                  1
# 5843  33007.0   5/6/2724 00:00:00    9/7/2724 00:00:00                  1
#
#       icustay_admit_age  ... icustay_last_careunit icustay_first_service  \
# 0              90.64270  ...                   CCU                  SICU
# 2              48.62681  ...                  MICU                  MICU
# 3              73.48396  ...                  FICU                  FICU
# 4              76.52892  ...                  MICU                  MICU
# 6              72.36841  ...                  CSRU                  SICU
# ...                 ...  ...                   ...                   ...
# 5839           88.09742  ...                  SICU                  SICU
# 5840           57.78417  ...                  CSRU                  MICU
# 5841           89.24603  ...                  CSRU                   CCU
# 5842           68.48606  ...                  CSRU                  MICU
# 5843           79.16299  ...                  CSRU                  MICU
#
#      icustay_last_service  height weight_first  weight_min  weight_max  \
# 0                    SICU     NaN         49.2        49.2        49.2
# 2                    MICU     NaN         72.4        72.4        72.4
# 3                    FICU  165.10         65.0        64.3        65.0
# 4                    MICU  179.07         96.8        96.8       108.0
# 6                    SICU     NaN         75.0        75.0        95.9
# ...                   ...     ...          ...         ...         ...
# 5839                 SICU     NaN         50.0        50.0        50.0
# 5840                 MICU  182.88         77.5        77.5        77.5
# 5841                 MICU     NaN         54.4        54.4        62.0
# 5842                 MICU     NaN         76.6        76.6        76.6
# 5843                 MICU     NaN         86.0        86.0        92.5
#
#       sapsi_max  sofa_max  matched_waveforms_num
# 0          17.0       5.0                    NaN
# 2          14.0       4.0                    NaN
# 3           NaN       5.0                    NaN
# 4          28.0      14.0                    NaN
# 6          22.0      12.0                    NaN
# ...         ...       ...                    ...
# 5839       16.0      10.0                    NaN
# 5840       26.0      18.0                    NaN
# 5841       22.0      12.0                    NaN
# 5842       21.0       8.0                    NaN
# 5843       21.0      10.0                    1.0
#
# [4811 rows x 22 columns]

# %%
icu.head()
# Out:
#    icustay_id  subject_id gender                 dob                  dod  \
# 0          62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 1          41          37      M  11/9/3195 00:00:00  31/12/3265 00:00:00
# 2          89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3          76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4           4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
#
#    hadm_id   hospital_admit_dt   hospital_disch_dt  icustay_total_num  \
# 0  28766.0  17/1/2644 00:00:00  23/1/2644 00:00:00                  1
# 1  18052.0  14/8/3264 00:00:00  19/8/3264 00:00:00                  1
# 2  15161.0  24/3/2778 00:00:00  27/3/2778 00:00:00                  1
# 3      NaN                 NaN                 NaN                  1
# 4   2075.0   7/9/2682 00:00:00  18/9/2682 00:00:00                  1
#
#    icustay_admit_age  ... icustay_last_careunit icustay_first_service  \
# 0           90.64270  ...                   CCU                  SICU
# 1           68.93134  ...                  MICU                  MICU
# 2           48.62681  ...                  MICU                  MICU
# 3           73.48396  ...                  FICU                  FICU
# 4           76.52892  ...                  MICU                  MICU
#
#   icustay_last_service  height weight_first  weight_min  weight_max  \
# 0                 SICU     NaN         49.2        49.2        49.2
# 1                 MICU     NaN          NaN         NaN         NaN
# 2                 MICU     NaN         72.4        72.4        72.4
# 3                 FICU  165.10         65.0        64.3        65.0
# 4                 MICU  179.07         96.8        96.8       108.0
#
#    sapsi_max  sofa_max  matched_waveforms_num
# 0       17.0       5.0                    NaN
# 1       11.0       2.0                    NaN
# 2       14.0       4.0                    NaN
# 3        NaN       5.0                    NaN
# 4       28.0      14.0                    NaN
#
# [5 rows x 22 columns]

# %%
icu = icu.drop('icustay_total_num', axis=1)
icu = icu.drop('icustay_expire_flg', axis=1)
icu = icu.drop('icustay_last_careunit', axis=1)
icu = icu.drop('icustay_first_service', axis=1)
icu = icu.drop('icustay_last_service', axis=1)
icu = icu.drop('height', axis=1)
icu = icu.drop('weight_max', axis=1)
icu = icu.drop('sapsi_max', axis=1)

# %%
icu.head()
# Out:
#    icustay_id  subject_id gender                 dob                  dod  \
# 0          62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 1          41          37      M  11/9/3195 00:00:00  31/12/3265 00:00:00
# 2          89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3          76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4           4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
#
#    hadm_id   hospital_admit_dt   hospital_disch_dt  icustay_admit_age  \
# 0  28766.0  17/1/2644 00:00:00  23/1/2644 00:00:00           90.64270
# 1  18052.0  14/8/3264 00:00:00  19/8/3264 00:00:00           68.93134
# 2  15161.0  24/3/2778 00:00:00  27/3/2778 00:00:00           48.62681
# 3      NaN                 NaN                 NaN           73.48396
# 4   2075.0   7/9/2682 00:00:00  18/9/2682 00:00:00           76.52892
#
#   icustay_first_careunit  weight_first  weight_min  sofa_max  \
# 0                    CCU          49.2        49.2       5.0
# 1                   MICU           NaN         NaN       2.0
# 2                   MICU          72.4        72.4       4.0
# 3                   FICU          65.0        64.3       5.0
# 4                   MICU          96.8        96.8      14.0
#
#    matched_waveforms_num
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
icu.columns
# Out:
# Index(['icustay_id', 'subject_id', 'gender', 'dob', 'dod', 'hadm_id',
#        'hospital_admit_dt', 'hospital_disch_dt', 'icustay_admit_age',
#        'icustay_first_careunit', 'weight_first', 'weight_min', 'sofa_max',
#        'matched_waveforms_num'],
#       dtype='object')

# %%
icu = icu.drop('hospital_admit_dt', axis=1)
icu = icu.drop('hospital_disch_dt', axis=1)
icu = icu.drop('icustay_first_careunit', axis=1)
icu = icu.drop('weight_min', axis=1)
icu = icu.drop('sofa_max', axis=1)
icu = icu.drop('matched_waveforms_num', axis=1)

# %%
icu.head()
# Out:
#    icustay_id  subject_id gender                 dob                  dod  \
# 0          62          56      F  26/5/2553 00:00:00   23/1/2644 00:00:00
# 1          41          37      M  11/9/3195 00:00:00  31/12/3265 00:00:00
# 2          89          78      M   8/8/2729 00:00:00   11/3/2781 00:00:00
# 3          76          67      M   4/6/2903 00:00:00  29/11/2976 00:00:00
# 4           4           3      M  28/2/2606 00:00:00    2/5/2683 00:00:00
#
#    hadm_id  icustay_admit_age  weight_first
# 0  28766.0           90.64270          49.2
# 1  18052.0           68.93134           NaN
# 2  15161.0           48.62681          72.4
# 3      NaN           73.48396          65.0
# 4   2075.0           76.52892          96.8

# %%
icu.dtypes
# Out:
# icustay_id             int64
# subject_id             int64
# gender                object
# dob                   object
# dod                   object
# hadm_id              float64
# icustay_admit_age    float64
# weight_first         float64
# dtype: object

# %%
chart.dtypes
# Out:
# hadm_id        int64
# subject_id     int64
# itemid         int64
# label         string
# icustay_id    object
# value1        string
# value1uom     string
# dtype: object

# %%
import pandas as pd
cols= ['subject_id', 'icustay_id', 'value1', 'value1uom']
chart[cols] = chart[cols].apply(pd.to_numeric, errors='coerce')
#chart.to_numeric(chart['subject_id'])
#chart.subject_id = chart.to_numeric(chart.subject_id, errors='coerce')

# %%
chart.head()
# Out:
#    hadm_id  subject_id  itemid      label  icustay_id  value1  value1uom
# 0     1459          83     198  GCS Total        94.0    15.0        NaN
# 1     1459          83     198  GCS Total        94.0    15.0        NaN
# 2     1459          83     198  GCS Total        94.0    15.0        NaN
# 3     1459          83     198  GCS Total        94.0    15.0        NaN
# 4     1459          83     198  GCS Total        94.0    15.0        NaN

# %%
chart = pd.merge(icu, chart)
chart.head()
# Out:
#    icustay_id  subject_id gender                 dob                 dod  \
# 0          62          56      F  26/5/2553 00:00:00  23/1/2644 00:00:00
# 1          62          56      F  26/5/2553 00:00:00  23/1/2644 00:00:00
# 2          62          56      F  26/5/2553 00:00:00  23/1/2644 00:00:00
# 3          62          56      F  26/5/2553 00:00:00  23/1/2644 00:00:00
# 4          62          56      F  26/5/2553 00:00:00  23/1/2644 00:00:00
#
#    hadm_id  icustay_admit_age  weight_first  itemid      label  value1  \
# 0  28766.0            90.6427          49.2     198  GCS Total     5.0
# 1  28766.0            90.6427          49.2     198  GCS Total    10.0
# 2  28766.0            90.6427          49.2     198  GCS Total    10.0
# 3  28766.0            90.6427          49.2     198  GCS Total    10.0
# 4  28766.0            90.6427          49.2     198  GCS Total    10.0
#
#    value1uom
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
chart = chart.drop('dob', axis=1)
chart = chart.drop('dod', axis=1)

# %%
chart.head()
# Out:
#    icustay_id  subject_id gender  hadm_id  icustay_admit_age  weight_first  \
# 0          62          56      F  28766.0            90.6427          49.2
# 1          62          56      F  28766.0            90.6427          49.2
# 2          62          56      F  28766.0            90.6427          49.2
# 3          62          56      F  28766.0            90.6427          49.2
# 4          62          56      F  28766.0            90.6427          49.2
#
#    itemid      label  value1  value1uom
# 0     198  GCS Total     5.0        NaN
# 1     198  GCS Total    10.0        NaN
# 2     198  GCS Total    10.0        NaN
# 3     198  GCS Total    10.0        NaN
# 4     198  GCS Total    10.0        NaN

# %% [markdown]
# put this into csv

# %%
chart.to_csv('newchart1.csv',sep='\t')

# %% [markdown]
# ## only take in cardiac arrest patients
# ic9.csv d_codeditems

# %%
ca=pd.read_csv("icd9.csv")

# %%
ca.head()
# Out:
#    subject_id  hadm_id  sequence    code  \
# 0          56    28766         1   198.3
# 1          56    28766         2   162.8
# 2          56    28766         3  531.40
# 3          56    28766         4   276.1
# 4          56    28766         5   428.0
#
#                                          description
# 0  SECONDARY MALIGNANT NEOPLASM OF BRAIN AND SPIN...
# 1  MALIGNANT NEOPLASM OF OTHER PARTS OF BRONCHUS ...
# 2  CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH HEMO...
# 3                  HYPOSMOLALITY AND/OR HYPONATREMIA
# 4               CONGESTIVE HEART FAILURE UNSPECIFIED

# %%
chart = pd.merge(chart, ca)

# %%
chart.head()
# Out:
#    icustay_id  subject_id gender  hadm_id  icustay_admit_age  weight_first  \
# 0          62          56      F  28766.0            90.6427          49.2
# 1          62          56      F  28766.0            90.6427          49.2
# 2          62          56      F  28766.0            90.6427          49.2
# 3          62          56      F  28766.0            90.6427          49.2
# 4          62          56      F  28766.0            90.6427          49.2
#
#    itemid      label  value1  value1uom  sequence    code  \
# 0     198  GCS Total     5.0        NaN         1   198.3
# 1     198  GCS Total     5.0        NaN         2   162.8
# 2     198  GCS Total     5.0        NaN         3  531.40
# 3     198  GCS Total     5.0        NaN         4   276.1
# 4     198  GCS Total     5.0        NaN         5   428.0
#
#                                          description
# 0  SECONDARY MALIGNANT NEOPLASM OF BRAIN AND SPIN...
# 1  MALIGNANT NEOPLASM OF OTHER PARTS OF BRONCHUS ...
# 2  CHRONIC OR UNSPECIFIED GASTRIC ULCER WITH HEMO...
# 3                  HYPOSMOLALITY AND/OR HYPONATREMIA
# 4               CONGESTIVE HEART FAILURE UNSPECIFIED

# %%
chart.dtypes
# Out:
# icustay_id             int64
# subject_id             int64
# gender                object
# hadm_id              float64
# icustay_admit_age    float64
# weight_first         float64
# itemid                 int64
# label                 string
# value1               float64
# value1uom            float64
# sequence               int64
# code                  object
# description           object
# dtype: object

# %%
#keep only cardiac arrest patients from chart['description]
chart['description'] = chart['description'].astype("string")

# %%
chart.dtypes
# Out:
# icustay_id             int64
# subject_id             int64
# gender                object
# hadm_id              float64
# icustay_admit_age    float64
# weight_first         float64
# itemid                 int64
# label                 string
# value1               float64
# value1uom            float64
# sequence               int64
# code                  object
# description           string
# dtype: object

# %%
chart[chart['description'].str.contains("CARDIAC ARREST")]
# Out:
#        icustay_id  subject_id gender  hadm_id  icustay_admit_age  \
# 596             4           3      M   2075.0           76.52892
# 605             4           3      M   2075.0           76.52892
# 614             4           3      M   2075.0           76.52892
# 623             4           3      M   2075.0           76.52892
# 632             4           3      M   2075.0           76.52892
# ...           ...         ...    ...      ...                ...
# 10433         123         106      M  24012.0           35.60950
# 10445         123         106      M  24012.0           35.60950
# 10457         123         106      M  24012.0           35.60950
# 10469         123         106      M  24012.0           35.60950
# 10481         123         106      M  24012.0           35.60950
#
#        weight_first  itemid             label  value1  value1uom  sequence  \
# 596            96.8     198         GCS Total    3.00        NaN         4
# 605            96.8     198         GCS Total    3.00        NaN         4
# 614            96.8     198         GCS Total    6.00        NaN         4
# 623            96.8     198         GCS Total    6.00        NaN         4
# 632            96.8     198         GCS Total   11.00        NaN         4
# ...             ...     ...               ...     ...        ...       ...
# 10433          68.9     780       Arterial pH    7.37        NaN         7
# 10445          68.9     837  Sodium (135-148)  136.00        NaN         7
# 10457          68.9    1162               BUN   16.00        NaN         7
# 10469          68.9    1525        Creatinine    1.20        NaN         7
# 10481          68.9    1535         Potassium    3.80        NaN         7
#
#         code     description
# 596    427.5  CARDIAC ARREST
# 605    427.5  CARDIAC ARREST
# 614    427.5  CARDIAC ARREST
# 623    427.5  CARDIAC ARREST
# 632    427.5  CARDIAC ARREST
# ...      ...             ...
# 10433  427.5  CARDIAC ARREST
# 10445  427.5  CARDIAC ARREST
# 10457  427.5  CARDIAC ARREST
# 10469  427.5  CARDIAC ARREST
# 10481  427.5  CARDIAC ARREST
#
# [269 rows x 13 columns]

# %%
#chart = chart.set_index('description').filter(like='CARDIAC ARREST', axis=0)

# %%
#chart['description'].filter(like='CARDIAC ARREST', axis=0)
# Out:
# Series([], Name: description, dtype: string)

# %%
chart = chart.drop('sequence', axis=1)
chart = chart.drop('code', axis=1)

# %%
chart.head()
# Out:
#                 icustay_id  subject_id gender  hadm_id  icustay_admit_age  \
# description
# CARDIAC ARREST           4           3      M   2075.0           76.52892
# CARDIAC ARREST           4           3      M   2075.0           76.52892
# CARDIAC ARREST           4           3      M   2075.0           76.52892
# CARDIAC ARREST           4           3      M   2075.0           76.52892
# CARDIAC ARREST           4           3      M   2075.0           76.52892
#
#                 weight_first  itemid      label  value1  value1uom
# description
# CARDIAC ARREST          96.8     198  GCS Total     3.0        NaN
# CARDIAC ARREST          96.8     198  GCS Total     3.0        NaN
# CARDIAC ARREST          96.8     198  GCS Total     6.0        NaN
# CARDIAC ARREST          96.8     198  GCS Total     6.0        NaN
# CARDIAC ARREST          96.8     198  GCS Total    11.0        NaN

# %%
chart.tail()
# Out:
#                 icustay_id  subject_id gender  hadm_id  icustay_admit_age  \
# description
# CARDIAC ARREST         123         106      M  24012.0            35.6095
# CARDIAC ARREST         123         106      M  24012.0            35.6095
# CARDIAC ARREST         123         106      M  24012.0            35.6095
# CARDIAC ARREST         123         106      M  24012.0            35.6095
# CARDIAC ARREST         123         106      M  24012.0            35.6095
#
#                 weight_first  itemid             label  value1  value1uom
# description
# CARDIAC ARREST          68.9     780       Arterial pH    7.37        NaN
# CARDIAC ARREST          68.9     837  Sodium (135-148)  136.00        NaN
# CARDIAC ARREST          68.9    1162               BUN   16.00        NaN
# CARDIAC ARREST          68.9    1525        Creatinine    1.20        NaN
# CARDIAC ARREST          68.9    1535         Potassium    3.80        NaN

# %% [markdown]
# ##save this final version

# %%
chart.to_csv('chartCA.csv',sep=',')
